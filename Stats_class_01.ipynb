# %% [markdown]
# <a href="https://colab.research.google.com/github/Prajaktaupadhayay-code/Computational-Stats/blob/main/Stats_class_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
a = 5
b = 7
c = a+b
c #this simply prints c
# Out:
# 12

# %%
ad_expense = [20, 10, 50, 70]
sales = [750, 500, 200, 360]
plt.plot (ad_expense , sales)
